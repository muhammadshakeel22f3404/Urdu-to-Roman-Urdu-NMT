# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/urdu_roman_nmt
# !pip install -r requirements.txt
# Out:
# /content/drive/MyDrive/urdu_roman_nmt
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 38.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 130.1 MB/s eta 0:00:00
# ...

# %%
# %cd /content/drive/MyDrive/urdu_roman_nmt
# !python -m nmt.train --config configs/exp1.json
# Out:
# /content/drive/MyDrive/urdu_roman_nmt
# [data] Loaded cached splits -> train: 10579  val: 5289  test: 5290
# [tok] Built tokenizers (bpe) at /content/drive/MyDrive/urdu_roman_nmt/outputs/exp1/tokenizer_src.json and /content/drive/MyDrive/urdu_roman_nmt/outputs/exp1/tokenizer_tgt.json
# [model] Parameters: 32,158,984
# Epoch 1/12 (TF=0.50): 100% 166/166 [00:17<00:00,  9.37it/s, loss/token=6.107107]
# [train] epoch 1: avg_loss/token=6.107107  ppl=449.04
# Evaluating: 100% 83/83 [00:06<00:00, 11.96it/s]
# [val] epoch 1: BLEU=0.01  PPL=29.07  CER=0.6528
# [ckpt] Saved new best to /content/drive/MyDrive/urdu_roman_nmt/outputs/exp1/best.pt (BLEU=0.01)
# [ckpt] Saved /content/drive/MyDrive/urdu_roman_nmt/outputs/exp1/epoch_1.pt
# Epoch 2/12 (TF=0.46): 100% 166/166 [00:16<00:00,  9.78it/s, loss/token=5.026644]
# [train] epoch 2: avg_loss/token=5.026644  ppl=152.42
# Evaluating: 100% 83/83 [00:07<00:00, 11.60it/s]
# [val] epoch 2: BLEU=0.02  PPL=20.85  CER=0.6488
# ...

# %%
# %cd /content/drive/MyDrive/urdu_roman_nmt
# !python -m experiments.run_experiments
# Out:
# /content/drive/MyDrive/urdu_roman_nmt
# Project root: /content/drive/MyDrive/urdu_roman_nmt
# Configs base: /content/drive/MyDrive/urdu_roman_nmt/configs
# Configs to run:
#  - /content/drive/MyDrive/urdu_roman_nmt/configs/exp1.json
#  - /content/drive/MyDrive/urdu_roman_nmt/configs/exp2.json
#  - /content/drive/MyDrive/urdu_roman_nmt/configs/exp3.json
# Running config: /content/drive/MyDrive/urdu_roman_nmt/configs/exp1.json
# [data] Loaded cached splits -> train: 10579  val: 5289  test: 5290
# [tok] Using cached tokenizers from /content/drive/MyDrive/urdu_roman_nmt/outputs/exp1 (type=bpe)
# [model] Parameters: 32,158,984
# Epoch 1/12 (TF=0.50): 100% 166/166 [00:16<00:00,  9.81it/s, loss/token=6.107107]
# [train] epoch 1: avg_loss/token=6.107107  ppl=449.04
# Evaluating: 100% 83/83 [00:06<00:00, 11.97it/s]
# [val] epoch 1: BLEU=0.01  PPL=29.07  CER=0.6528
# [ckpt] Saved new best to /content/drive/MyDrive/urdu_roman_nmt/outputs/exp1/best.pt (BLEU=0.01)
# ...

# %%
# %cd /content/drive/MyDrive/urdu_roman_nmt
# !python -m nmt.infer --ckpt outputs/exp1/best.pt --input "خدا بندے سے خود پوچھے بتا تیری رضا کیا ہے" "خودی کو کر بلند اتنا کہ ہر تقدیر سے پہلے"
# Out:
# /content/drive/MyDrive/urdu_roman_nmt
# URDU: خدا بندے سے خود پوچھے بتا تیری رضا کیا ہے
# ROMAN: khwd se se se tyry tyry kya kya kya he
# ----------------------------------------
# URDU: خودی کو کر بلند اتنا کہ ہر تقدیر سے پہلے
# ROMAN: atna kw atna atna atna atna atna tqdyr tqdyr phle
# ----------------------------------------

# %%
# %cd /content/drive/MyDrive/urdu_roman_nmt
# !python -m nmt.infer --ckpt outputs/exp2/best.pt --input "خدا بندے سے خود پوچھے بتا تیری رضا کیا ہے" "خودی کو کر بلند اتنا کہ ہر تقدیر سے پہلے"
# Out:
# /content/drive/MyDrive/urdu_roman_nmt
# URDU: خدا بندے سے خود پوچھے بتا تیری رضا کیا ہے
# ROMAN: khda khwd se khwd khwd khwd khwd kya kya he
# ----------------------------------------
# URDU: خودی کو کر بلند اتنا کہ ہر تقدیر سے پہلے
# ROMAN: khwdy kw blnd kr blnd blnd tqdyr tqdyr se
# ----------------------------------------

# %%
# %cd /content/drive/MyDrive/urdu_roman_nmt
# !python -m nmt.infer --ckpt outputs/exp3/best.pt --input "خدا بندے سے خود پوچھے بتا تیری رضا کیا ہے" "خودی کو کر بلند اتنا کہ ہر تقدیر سے پہلے"
# Out:
# /content/drive/MyDrive/urdu_roman_nmt
# URDU: خدا بندے سے خود پوچھے بتا تیری رضا کیا ہے
# ROMAN: khdawn se khwd pwchھe bta tyry bar kya he
# ----------------------------------------
# URDU: خودی کو کر بلند اتنا کہ ہر تقدیر سے پہلے
# ROMAN: khwdy kw kr blnd atna kh hr tqdyr se phle
# ----------------------------------------
